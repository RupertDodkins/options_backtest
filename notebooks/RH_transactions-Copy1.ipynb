# %%
import pandas as pd
df = pd.read_csv('~/Downloads/RHTradeHistory (1).csv', index_col=False)
df.head()
# Out:
# /var/folders/1x/4jypbkmx6rz03t2116nn6_g00000gn/T/ipykernel_25209/3574296549.py:2: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv('~/Downloads/RHTradeHistory (1).csv', index_col=False)
#        date         time    type                      symbol action  quantity  \
# 0  9/2/2022   7:13:00 AM  option     TSLA $265 Call 9/2/2022    BTC  1.000000
# 1  9/2/2022   7:13:00 AM  option     TSLA $265 Call 9/9/2022    STO  1.000000
# 2  9/1/2022  10:34:00 AM   stock                        TSLA    Buy  0.110967
# 3  9/1/2022  11:32:00 AM  option  TSLA $273.33 Call 9/2/2022    BTC  1.000000
# 4  9/1/2022  11:32:00 AM  option     TSLA $280 Call 9/2/2022    STO  1.000000
#
#     price  amount  fees                                           details
# 0   12.10  1210.0     0  Part of Consolidated Transaction (such as an I...
# 1   15.05  1505.0     0  Part of Consolidated Transaction (such as an I...
# 2  270.35    30.0     0                                                NaN
# 3    3.38   338.0     0  Part of Consolidated Transaction (such as an I...
# 4    0.97    97.0     0  Part of Consolidated Transaction (such as an I...

# %%
df = df[df['type'] == 'option']

# %%
def parse_type(symbol_col):
    symbol_df = pd.DataFrame(index=symbol_col.index, columns=['ticker', 'strike', 'option_type', 'expiration'])
    for i in range(len(symbol_col)):
        parsed_data = symbol_col.iloc[i].split(' ')
        # if not np.all(np.array(parsed_data) == 'TSLA'):
        symbol_df.iloc[i] = parsed_data
    return symbol_df

def parse_action(action_col):
    action_df = pd.DataFrame(index=action_col.index, columns=['transaction', 'state'])
    for i in range(len(action_col)):
        parsed_data = action_col.iloc[i].split('T')
        action_df.iloc[i] = parsed_data
    return action_df

# %%
symbol_df = parse_type(df['symbol'])
action_df = parse_action(df['action'])
df = pd.concat((df, symbol_df, action_df), axis=1)

# %%
df = df.drop(labels=['type', 'symbol', 'fees', 'ticker', 'details ', 'action', 'amount'], axis=1)

# %%
df
# Out:
#          date         time  quantity  price   strike option_type expiration  \
# 0    9/2/2022   7:13:00 AM       1.0  12.10     $265        Call   9/2/2022
# 1    9/2/2022   7:13:00 AM       1.0  15.05     $265        Call   9/9/2022
# 3    9/1/2022  11:32:00 AM       1.0   3.38  $273.33        Call   9/2/2022
# 4    9/1/2022  11:32:00 AM       1.0   0.97     $280        Call   9/2/2022
# 5    9/1/2022   8:04:00 AM       2.0   5.82     $265        Call   9/2/2022
# 6    9/1/2022   8:04:00 AM       2.0   2.41  $271.67        Call   9/2/2022
# 7    9/1/2022   8:04:00 AM       2.0  13.87     $265        Call  9/16/2022
# 8    9/1/2022   8:04:00 AM       2.0  10.31  $271.67        Call  9/16/2022
# 10  8/31/2022   6:32:00 AM       1.0   1.59  $268.33         Put   9/2/2022
# 11  8/31/2022   6:32:00 AM       1.0   1.95     $270         Put   9/2/2022
# 13  8/30/2022   9:33:00 AM       1.0   8.69  $273.33        Call   9/2/2022
# 14  8/30/2022   9:33:00 AM       1.0   5.02     $280        Call   9/2/2022
# 15  8/30/2022   9:25:00 AM       2.0  10.58  $271.67        Call   9/2/2022
# 16  8/30/2022   9:25:00 AM       2.0   5.58     $280        Call   9/2/2022
# 17  8/30/2022   7:31:00 AM       1.0   1.31  $268.33         Put   9/2/2022
# 18  8/30/2022   7:31:00 AM       1.0   1.56     $270         Put   9/2/2022
# 20  8/29/2022   6:33:00 AM       3.0   8.66     $280        Call   9/2/2022
# 21  8/29/2022   6:33:00 AM       3.0   1.37  $301.67        Call   9/2/2022
# 23  8/26/2022  12:40:00 PM       3.0   2.81  $301.67        Call   9/2/2022
# 24  8/26/2022  12:01:00 PM       3.0   0.46     $290        Call  8/26/2022
# 26  8/26/2022   7:00:00 AM       3.0  12.75     $285        Call  8/26/2022
# 27  8/26/2022   7:00:00 AM       3.0   8.03     $290        Call  8/26/2022
# 28  8/26/2022   7:00:00 AM       3.0  35.21  $266.67        Call  9/16/2022
# 29  8/26/2022   7:00:00 AM       3.0  31.04  $271.67        Call  9/16/2022
#
#    transaction state
# 0            B     C
# 1            S     O
# 3            B     C
# 4            S     O
# 5            S     O
# 6            B     C
# 7            B     O
# 8            S     C
# 10           S     C
# 11           B     C
# 13           S     O
# 14           B     C
# 15           S     O
# 16           B     C
# 17           B     O
# 18           S     O
# 20           S     O
# 21           B     C
# 23           S     O
# 24           B     C
# 26           B     C
# 27           S     O
# 28           S     C
# 29           B     O

# %%
df = df.loc[::-1].reset_index(drop=True)

# %%
df
# Out:
#          date         time  quantity  price   strike option_type expiration  \
# 0   8/26/2022   7:00:00 AM       3.0  31.04  $271.67        Call  9/16/2022
# 1   8/26/2022   7:00:00 AM       3.0  35.21  $266.67        Call  9/16/2022
# 2   8/26/2022   7:00:00 AM       3.0   8.03     $290        Call  8/26/2022
# 3   8/26/2022   7:00:00 AM       3.0  12.75     $285        Call  8/26/2022
# 4   8/26/2022  12:01:00 PM       3.0   0.46     $290        Call  8/26/2022
# 5   8/26/2022  12:40:00 PM       3.0   2.81  $301.67        Call   9/2/2022
# 6   8/29/2022   6:33:00 AM       3.0   1.37  $301.67        Call   9/2/2022
# 7   8/29/2022   6:33:00 AM       3.0   8.66     $280        Call   9/2/2022
# 8   8/30/2022   7:31:00 AM       1.0   1.56     $270         Put   9/2/2022
# 9   8/30/2022   7:31:00 AM       1.0   1.31  $268.33         Put   9/2/2022
# 10  8/30/2022   9:25:00 AM       2.0   5.58     $280        Call   9/2/2022
# 11  8/30/2022   9:25:00 AM       2.0  10.58  $271.67        Call   9/2/2022
# 12  8/30/2022   9:33:00 AM       1.0   5.02     $280        Call   9/2/2022
# 13  8/30/2022   9:33:00 AM       1.0   8.69  $273.33        Call   9/2/2022
# 14  8/31/2022   6:32:00 AM       1.0   1.95     $270         Put   9/2/2022
# 15  8/31/2022   6:32:00 AM       1.0   1.59  $268.33         Put   9/2/2022
# 16   9/1/2022   8:04:00 AM       2.0  10.31  $271.67        Call  9/16/2022
# 17   9/1/2022   8:04:00 AM       2.0  13.87     $265        Call  9/16/2022
# 18   9/1/2022   8:04:00 AM       2.0   2.41  $271.67        Call   9/2/2022
# 19   9/1/2022   8:04:00 AM       2.0   5.82     $265        Call   9/2/2022
# 20   9/1/2022  11:32:00 AM       1.0   0.97     $280        Call   9/2/2022
# 21   9/1/2022  11:32:00 AM       1.0   3.38  $273.33        Call   9/2/2022
# 22   9/2/2022   7:13:00 AM       1.0  15.05     $265        Call   9/9/2022
# 23   9/2/2022   7:13:00 AM       1.0  12.10     $265        Call   9/2/2022
#
#    transaction state
# 0            B     O
# 1            S     C
# 2            S     O
# 3            B     C
# 4            B     C
# 5            S     O
# 6            B     C
# 7            S     O
# 8            S     O
# 9            B     O
# 10           B     C
# 11           S     O
# 12           B     C
# 13           S     O
# 14           B     C
# 15           S     C
# 16           S     C
# 17           B     O
# 18           B     C
# 19           S     O
# 20           S     O
# 21           B     C
# 22           S     O
# 23           B     C

# %%
def expand_df(df):
    expanded_df = pd.DataFrame(index=np.arange(np.sum(df['quantity']), dtype=np.int), columns=df.columns)
    exp_ind = 0
    for ind, df_row in df.iterrows():
        quantity = int(df_row['quantity'])
        df_row['quantity'] = 1.
        expanded_df.iloc[exp_ind:exp_ind+quantity] = df_row
        # expanded_df.iloc[exp_ind:exp_ind+quantity]['quantity'] = 1.0
        exp_ind += quantity
    return expanded_df

# %%
df = expand_df(df)
df
# Out:
#          date         time quantity  price   strike option_type expiration  \
# 0   8/26/2022   7:00:00 AM      1.0  31.04  $271.67        Call  9/16/2022
# 1   8/26/2022   7:00:00 AM      1.0  31.04  $271.67        Call  9/16/2022
# 2   8/26/2022   7:00:00 AM      1.0  31.04  $271.67        Call  9/16/2022
# 3   8/26/2022   7:00:00 AM      1.0  35.21  $266.67        Call  9/16/2022
# 4   8/26/2022   7:00:00 AM      1.0  35.21  $266.67        Call  9/16/2022
# 5   8/26/2022   7:00:00 AM      1.0  35.21  $266.67        Call  9/16/2022
# 6   8/26/2022   7:00:00 AM      1.0   8.03     $290        Call  8/26/2022
# 7   8/26/2022   7:00:00 AM      1.0   8.03     $290        Call  8/26/2022
# 8   8/26/2022   7:00:00 AM      1.0   8.03     $290        Call  8/26/2022
# 9   8/26/2022   7:00:00 AM      1.0  12.75     $285        Call  8/26/2022
# 10  8/26/2022   7:00:00 AM      1.0  12.75     $285        Call  8/26/2022
# 11  8/26/2022   7:00:00 AM      1.0  12.75     $285        Call  8/26/2022
# 12  8/26/2022  12:01:00 PM      1.0   0.46     $290        Call  8/26/2022
# 13  8/26/2022  12:01:00 PM      1.0   0.46     $290        Call  8/26/2022
# 14  8/26/2022  12:01:00 PM      1.0   0.46     $290        Call  8/26/2022
# 15  8/26/2022  12:40:00 PM      1.0   2.81  $301.67        Call   9/2/2022
# 16  8/26/2022  12:40:00 PM      1.0   2.81  $301.67        Call   9/2/2022
# 17  8/26/2022  12:40:00 PM      1.0   2.81  $301.67        Call   9/2/2022
# 18  8/29/2022   6:33:00 AM      1.0   1.37  $301.67        Call   9/2/2022
# 19  8/29/2022   6:33:00 AM      1.0   1.37  $301.67        Call   9/2/2022
# 20  8/29/2022   6:33:00 AM      1.0   1.37  $301.67        Call   9/2/2022
# 21  8/29/2022   6:33:00 AM      1.0   8.66     $280        Call   9/2/2022
# 22  8/29/2022   6:33:00 AM      1.0   8.66     $280        Call   9/2/2022
# 23  8/29/2022   6:33:00 AM      1.0   8.66     $280        Call   9/2/2022
# 24  8/30/2022   7:31:00 AM      1.0   1.56     $270         Put   9/2/2022
# 25  8/30/2022   7:31:00 AM      1.0   1.31  $268.33         Put   9/2/2022
# 26  8/30/2022   9:25:00 AM      1.0   5.58     $280        Call   9/2/2022
# 27  8/30/2022   9:25:00 AM      1.0   5.58     $280        Call   9/2/2022
# 28  8/30/2022   9:25:00 AM      1.0  10.58  $271.67        Call   9/2/2022
# 29  8/30/2022   9:25:00 AM      1.0  10.58  $271.67        Call   9/2/2022
# 30  8/30/2022   9:33:00 AM      1.0   5.02     $280        Call   9/2/2022
# 31  8/30/2022   9:33:00 AM      1.0   8.69  $273.33        Call   9/2/2022
# 32  8/31/2022   6:32:00 AM      1.0   1.95     $270         Put   9/2/2022
# 33  8/31/2022   6:32:00 AM      1.0   1.59  $268.33         Put   9/2/2022
# 34   9/1/2022   8:04:00 AM      1.0  10.31  $271.67        Call  9/16/2022
# 35   9/1/2022   8:04:00 AM      1.0  10.31  $271.67        Call  9/16/2022
# 36   9/1/2022   8:04:00 AM      1.0  13.87     $265        Call  9/16/2022
# 37   9/1/2022   8:04:00 AM      1.0  13.87     $265        Call  9/16/2022
# 38   9/1/2022   8:04:00 AM      1.0   2.41  $271.67        Call   9/2/2022
# 39   9/1/2022   8:04:00 AM      1.0   2.41  $271.67        Call   9/2/2022
# 40   9/1/2022   8:04:00 AM      1.0   5.82     $265        Call   9/2/2022
# 41   9/1/2022   8:04:00 AM      1.0   5.82     $265        Call   9/2/2022
# 42   9/1/2022  11:32:00 AM      1.0   0.97     $280        Call   9/2/2022
# 43   9/1/2022  11:32:00 AM      1.0   3.38  $273.33        Call   9/2/2022
# 44   9/2/2022   7:13:00 AM      1.0  15.05     $265        Call   9/9/2022
# 45   9/2/2022   7:13:00 AM      1.0   12.1     $265        Call   9/2/2022
#
#    transaction state
# 0            B     O
# 1            B     O
# 2            B     O
# 3            S     C
# 4            S     C
# 5            S     C
# 6            S     O
# 7            S     O
# 8            S     O
# 9            B     C
# 10           B     C
# 11           B     C
# 12           B     C
# 13           B     C
# 14           B     C
# 15           S     O
# 16           S     O
# 17           S     O
# 18           B     C
# 19           B     C
# 20           B     C
# 21           S     O
# 22           S     O
# 23           S     O
# 24           S     O
# 25           B     O
# 26           B     C
# 27           B     C
# 28           S     O
# 29           S     O
# 30           B     C
# 31           S     O
# 32           B     C
# 33           S     C
# 34           S     C
# 35           S     C
# 36           B     O
# 37           B     O
# 38           B     C
# 39           B     C
# 40           S     O
# 41           S     O
# 42           S     O
# 43           B     C
# 44           S     O
# 45           B     C

# %%
def creat_option_plays(df):
    option_opens = df[df['state'] == 'O'].reset_index(drop=True)
    option_closes = df[df['state'] == 'C'].reset_index(drop=True)
    option_plays = pd.DataFrame(index=np.arange(len(option_opens)),
                                columns=['open', 'close', 'expiration',  'strike', 'option_type', 'quantity', 'filled', 'closed', 'P/L'])
    for ind, row in option_opens.iterrows():
        option_plays.iloc[ind] = list(row[['date']]) + [0] + list(row[['expiration', 'strike', 'option_type','quantity', 'price']]) + [np.nan, 0]
        if row['transaction'] == 'B':
            option_plays.iloc[ind]['filled'] *= -1

    name_list = ['strike', 'option_type', 'expiration']
    for ind, play_row in option_plays.iterrows():
        match_ind = (option_closes[name_list] == play_row[name_list]).all(axis=1)
        matched_df = option_closes.loc[match_ind]
        if len(matched_df) > 0:
            option_plays.iloc[ind]['close'] = matched_df.iloc[0]['date']
            option_plays.iloc[ind]['closed'] = matched_df.iloc[0]['price']
            if matched_df.iloc[0]['transaction'] == 'S':
                option_plays.iloc[ind]['closed'] *= -1
            option_closes = option_closes.drop(matched_df.index[0], axis=0)
            
    option_plays['P/L'] = option_plays['filled'] - option_plays['closed']
    return option_plays
option_plays = creat_option_plays(df)

# %%
option_plays
# Out:
#          open      close expiration   strike option_type quantity filled  \
# 0   8/26/2022   9/1/2022  9/16/2022  $271.67        Call      1.0 -31.04
# 1   8/26/2022   9/1/2022  9/16/2022  $271.67        Call      1.0 -31.04
# 2   8/26/2022          0  9/16/2022  $271.67        Call      1.0 -31.04
# 3   8/26/2022  8/26/2022  8/26/2022     $290        Call      1.0   8.03
# 4   8/26/2022  8/26/2022  8/26/2022     $290        Call      1.0   8.03
# 5   8/26/2022  8/26/2022  8/26/2022     $290        Call      1.0   8.03
# 6   8/26/2022  8/29/2022   9/2/2022  $301.67        Call      1.0   2.81
# 7   8/26/2022  8/29/2022   9/2/2022  $301.67        Call      1.0   2.81
# 8   8/26/2022  8/29/2022   9/2/2022  $301.67        Call      1.0   2.81
# 9   8/29/2022  8/30/2022   9/2/2022     $280        Call      1.0   8.66
# 10  8/29/2022  8/30/2022   9/2/2022     $280        Call      1.0   8.66
# 11  8/29/2022  8/30/2022   9/2/2022     $280        Call      1.0   8.66
# 12  8/30/2022  8/31/2022   9/2/2022     $270         Put      1.0   1.56
# 13  8/30/2022  8/31/2022   9/2/2022  $268.33         Put      1.0  -1.31
# 14  8/30/2022   9/1/2022   9/2/2022  $271.67        Call      1.0  10.58
# 15  8/30/2022   9/1/2022   9/2/2022  $271.67        Call      1.0  10.58
# 16  8/30/2022   9/1/2022   9/2/2022  $273.33        Call      1.0   8.69
# 17   9/1/2022          0  9/16/2022     $265        Call      1.0 -13.87
# 18   9/1/2022          0  9/16/2022     $265        Call      1.0 -13.87
# 19   9/1/2022   9/2/2022   9/2/2022     $265        Call      1.0   5.82
# 20   9/1/2022          0   9/2/2022     $265        Call      1.0   5.82
# 21   9/1/2022          0   9/2/2022     $280        Call      1.0   0.97
# 22   9/2/2022          0   9/9/2022     $265        Call      1.0  15.05
#
#    closed    P/L
# 0  -10.31 -20.73
# 1  -10.31 -20.73
# 2     NaN    NaN
# 3    0.46   7.57
# 4    0.46   7.57
# 5    0.46   7.57
# 6    1.37   1.44
# 7    1.37   1.44
# 8    1.37   1.44
# 9    5.58   3.08
# 10   5.58   3.08
# 11   5.02   3.64
# 12   1.95  -0.39
# 13  -1.59   0.28
# 14   2.41   8.17
# 15   2.41   8.17
# 16   3.38   5.31
# 17    NaN    NaN
# 18    NaN    NaN
# 19   12.1  -6.28
# 20    NaN    NaN
# 21    NaN    NaN
# 22    NaN    NaN

# %%
(np.array(option_plays['P/L'])[np.logical_not([np.isnan(m) for m in np.array(option_plays['P/L'])])]).cumsum()
# Out:
# array([-20.729999999999997, -41.459999999999994, -33.88999999999999,
#        -26.319999999999993, -18.749999999999993, -17.30999999999999,
#        -15.869999999999992, -14.429999999999993, -11.349999999999993,
#        -8.269999999999992, -4.629999999999992, -5.019999999999992,
#        -4.739999999999991, 3.4300000000000086, 11.600000000000009,
#        16.910000000000007, 10.630000000000008], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.plot(pd.to_datetime(option_plays['open']),option_plays['P/L'].cumsum())

# %%
option_plays[(option_plays['expiration'] == '9/2/2022') & (option_plays['strike'] == '$273.33')]
# Out:
#          open     close expiration   strike option_type quantity filled  \
# 16  8/30/2022  9/1/2022   9/2/2022  $273.33        Call      1.0   8.69
#
#    closed P/L
# 16   3.38   0

# %%
import opstrat as op

# %%
import opstrat as op
#Declare parameters
K=200    #spot price
St=208   #current stock price
r=3.2      #4% risk free rate
t=30     #time to expiry, 30 days 
v=20     #volatility 
type='c' #Option type call
#Black Scholes Model
bsm=op.black_scholes(K=K, St=St, r=r, t=t, 
                     v=v, type='c')
bsm
# Out:
# {'value': {'option value': 10.110842067482452,
#   'intrinsic value': 8,
#   'time value': 2.1108420674824515},
#  'greeks': {'delta': 0.7759431769519206,
#   'gamma': 0.02508718572191462,
#   'theta': -0.07273581068792007,
#   'vega': 0.17841731557362972,
#   'rho': 0.12434411403165782}}

# %%
K=270    #spot price
St=270   #current stock price
r=3.2      #4% risk free rate
t=7     #time to expiry, 30 days 
v=50.69     #volatility 
type='c' #Option type call
#Black Scholes Model
bsm=op.black_scholes(K=K, St=St, r=r, t=t, 
                     v=v, type='c')
bsm
# Out:
# {'value': {'option value': 7.640580340369951,
#   'intrinsic value': 0,
#   'time value': 7.640580340369951},
#  'greeks': {'delta': 0.5174845881337765,
#   'gamma': 0.021028294504828106,
#   'theta': -0.5511564803605808,
#   'vega': 0.14902497095449338,
#   'rho': 0.025330460525760223}}

# %%
K=275    #spot price
St=270.23   #current stock price
r=3.2      #4% risk free rate
t=7     #time to expiry, 30 days 
v=46     #volatility 
type='c' #Option type call
#Black Scholes Model
bsm=op.black_scholes(K=K, St=St, r=r, t=t, 
                     v=v, type='c')
bsm['value']['option value'], bsm['greeks']
# Out:
# (4.865963004398225,
#  {'delta': 0.40780700317631746,
#   'gamma': 0.022553199532061235,
#   'theta': -0.4866191642545752,
#   'vega': 0.1452908591559878,
#   'rho': 0.020201371623221})

# %%
from yahoo_fin.stock_info import get_data

# %%
tsla = get_data("tsla", start_date="08/01/2022", end_date="09/02/2022", index_as_date = True, interval="1d")
tsla
# Out:
#                   open        high         low       close    adjclose  \
# 2022-08-01  301.276672  311.876678  295.000000  297.276672  297.276672
# 2022-08-02  294.003326  307.833344  292.666656  300.586670  300.586670
# 2022-08-03  305.000000  309.549988  301.149994  307.396667  307.396667
# 2022-08-04  311.000000  313.606659  305.000000  308.633331  308.633331
# 2022-08-05  302.670013  304.606659  285.543335  288.170013  288.170013
# 2022-08-08  295.000000  305.200012  289.086670  290.423340  290.423340
# 2022-08-09  290.293335  292.396667  279.353333  283.333344  283.333344
# 2022-08-10  297.066681  297.510010  283.369995  294.356659  294.356659
# 2022-08-11  296.513336  298.236664  285.833344  286.630005  286.630005
# 2022-08-12  289.416656  300.160004  285.033325  300.029999  300.029999
# 2022-08-15  301.786682  313.133331  301.230011  309.320007  309.320007
# 2022-08-16  311.666656  314.666656  302.883331  306.563324  306.563324
# 2022-08-17  303.396667  309.656677  300.033325  303.996674  303.996674
# 2022-08-18  306.000000  306.500000  301.853333  302.869995  302.869995
# 2022-08-19  299.000000  300.359985  292.500000  296.666656  296.666656
# 2022-08-22  291.913330  292.399994  286.296661  289.913330  289.913330
# 2022-08-23  291.453339  298.826660  287.923340  296.453339  296.453339
# 2022-08-24  297.563324  303.646667  296.500000  297.096680  297.096680
# 2022-08-25  302.359985  302.959991  291.600006  296.070007  296.070007
# 2022-08-26  297.429993  302.000000  287.470001  288.089996  288.089996
# 2022-08-29  282.829987  287.739990  280.700012  284.820007  284.820007
# 2022-08-30  287.869995  288.480011  272.649994  277.700012  277.700012
# 2022-08-31  280.619995  281.250000  271.809998  275.609985  275.609985
# 2022-09-01  272.579987  277.579987  266.149994  277.160004  277.160004
#
#                volume ticker
# 2022-08-01  117042900   TSLA
# 2022-08-02   95577600   TSLA
# 2022-08-03   80091000   TSLA
# 2022-08-04   72256200   TSLA
# 2022-08-05  113172900   TSLA
# 2022-08-08   98994000   TSLA
# 2022-08-09   86244600   TSLA
# 2022-08-10   94918800   TSLA
# 2022-08-11   70155000   TSLA
# 2022-08-12   79657200   TSLA
# 2022-08-15   89359200   TSLA
# 2022-08-16   88136400   TSLA
# 2022-08-17   68766000   TSLA
# 2022-08-18   47500500   TSLA
# 2022-08-19   61395300   TSLA
# 2022-08-22   55843200   TSLA
# 2022-08-23   63984900   TSLA
# 2022-08-24   57259800   TSLA
# 2022-08-25   53230000   TSLA
# 2022-08-26   57163900   TSLA
# 2022-08-29   41864700   TSLA
# 2022-08-30   50541800   TSLA
# 2022-08-31   52107300   TSLA
# 2022-09-01   54287000   TSLA
